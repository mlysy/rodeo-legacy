# %%
from test_square_exp import test_cov_se
from test_rect import test_cov_re
from test_exp import test_cov_ex
import matplotlib.pyplot as plt

# %%
import numpy as np
import scipy.stats as scs
ntest = 3
alpha, gamma = 1, 1

nT = scs.randint.rvs(2, 10, size = 1)
tseq = abs(scs.norm.rvs(size = nT))

# %% [markdown]
# # Square Exponential Test

# %%
Sigma_an_vv_se, Sigma_an_xx_se, Sigma_an_xv_se, Sigma_nu_vv_se, Sigma_nu_xx_se, Sigma_nu_xv_se = test_cov_se(tseq)

# %%
plt.plot(Sigma_an_vv_se, Sigma_nu_vv_se)
plt.show()

# %%
plt.plot(Sigma_an_xv_se, Sigma_nu_xv_se)
plt.show()

# %%
plt.plot(Sigma_an_xx_se, Sigma_nu_xx_se)
plt.show()

# %% [markdown]
# # Rectangular Test

# %%
Sigma_an_vv_re, Sigma_an_xx_re, Sigma_an_xv_re, Sigma_nu_vv_re, Sigma_nu_xx_re, Sigma_nu_xv_re = test_cov_re(tseq)
# Out:
# C:\Users\mohan\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\integrate\quadpack.py:385: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)

# %%
plt.plot(Sigma_an_vv_re, Sigma_nu_vv_re)
plt.show()

# %%
plt.plot(Sigma_an_xx_re, Sigma_nu_xx_re)
plt.show()

# %%
plt.plot(Sigma_an_xv_re, Sigma_nu_xv_re)
plt.show()

# %% [markdown]
# # Exponential Test

# %%
Sigma_an_xx_ex, Sigma_an_xv_ex, Sigma_nu_xx_ex, Sigma_nu_xv_ex = test_cov_ex(tseq)

# %%
plt.plot(Sigma_an_xx_ex, Sigma_nu_xx_ex)
plt.show()

# %%
plt.plot(Sigma_an_xv_ex, Sigma_nu_xv_ex)
plt.show()
